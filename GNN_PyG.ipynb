# %%
# Install required packages.
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.10.0+cu113.html
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git

# %%
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader

# %%
train_dataset = torch.load('train.pt')
test_dataset = torch.load('test.pt')

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(data)
    print()
# Out:
# Step 1:
# =======
# DataBatch(x=[1140, 11], edge_index=[2, 2364], edge_attr=[2364, 4], y=[64], pos=[1140, 3], name=[64], batch=[1140], ptr=[65])
#
# Step 2:
# =======
# DataBatch(x=[1128, 11], edge_index=[2, 2344], edge_attr=[2344, 4], y=[64], pos=[1128, 3], name=[64], batch=[1128], ptr=[65])
#
# Step 3:
# =======
# DataBatch(x=[1160, 11], edge_index=[2, 2384], edge_attr=[2384, 4], y=[64], pos=[1160, 3], name=[64], batch=[1160], ptr=[65])
#
# Step 4:
# =======
# DataBatch(x=[1148, 11], edge_index=[2, 2358], edge_attr=[2358, 4], y=[64], pos=[1148, 3], name=[64], batch=[1148], ptr=[65])
#
# Step 5:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2352], edge_attr=[2352, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 6:
# =======
# DataBatch(x=[1148, 11], edge_index=[2, 2382], edge_attr=[2382, 4], y=[64], pos=[1148, 3], name=[64], batch=[1148], ptr=[65])
#
# Step 7:
# =======
# DataBatch(x=[1174, 11], edge_index=[2, 2430], edge_attr=[2430, 4], y=[64], pos=[1174, 3], name=[64], batch=[1174], ptr=[65])
#
# Step 8:
# =======
# DataBatch(x=[1209, 11], edge_index=[2, 2494], edge_attr=[2494, 4], y=[64], pos=[1209, 3], name=[64], batch=[1209], ptr=[65])
#
# Step 9:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2368], edge_attr=[2368, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 10:
# =======
# DataBatch(x=[1160, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1160, 3], name=[64], batch=[1160], ptr=[65])
#
# Step 11:
# =======
# DataBatch(x=[1174, 11], edge_index=[2, 2418], edge_attr=[2418, 4], y=[64], pos=[1174, 3], name=[64], batch=[1174], ptr=[65])
#
# Step 12:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2356], edge_attr=[2356, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 13:
# =======
# DataBatch(x=[1115, 11], edge_index=[2, 2286], edge_attr=[2286, 4], y=[64], pos=[1115, 3], name=[64], batch=[1115], ptr=[65])
#
# Step 14:
# =======
# DataBatch(x=[1176, 11], edge_index=[2, 2424], edge_attr=[2424, 4], y=[64], pos=[1176, 3], name=[64], batch=[1176], ptr=[65])
#
# Step 15:
# =======
# DataBatch(x=[1151, 11], edge_index=[2, 2382], edge_attr=[2382, 4], y=[64], pos=[1151, 3], name=[64], batch=[1151], ptr=[65])
#
# Step 16:
# =======
# DataBatch(x=[1168, 11], edge_index=[2, 2440], edge_attr=[2440, 4], y=[64], pos=[1168, 3], name=[64], batch=[1168], ptr=[65])
#
# Step 17:
# =======
# DataBatch(x=[1175, 11], edge_index=[2, 2420], edge_attr=[2420, 4], y=[64], pos=[1175, 3], name=[64], batch=[1175], ptr=[65])
#
# Step 18:
# =======
# DataBatch(x=[1130, 11], edge_index=[2, 2386], edge_attr=[2386, 4], y=[64], pos=[1130, 3], name=[64], batch=[1130], ptr=[65])
#
# Step 19:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2368], edge_attr=[2368, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 20:
# =======
# DataBatch(x=[1188, 11], edge_index=[2, 2470], edge_attr=[2470, 4], y=[64], pos=[1188, 3], name=[64], batch=[1188], ptr=[65])
#
# Step 21:
# =======
# DataBatch(x=[1149, 11], edge_index=[2, 2376], edge_attr=[2376, 4], y=[64], pos=[1149, 3], name=[64], batch=[1149], ptr=[65])
#
# Step 22:
# =======
# DataBatch(x=[1148, 11], edge_index=[2, 2360], edge_attr=[2360, 4], y=[64], pos=[1148, 3], name=[64], batch=[1148], ptr=[65])
#
# Step 23:
# =======
# DataBatch(x=[1175, 11], edge_index=[2, 2456], edge_attr=[2456, 4], y=[64], pos=[1175, 3], name=[64], batch=[1175], ptr=[65])
#
# Step 24:
# =======
# DataBatch(x=[1136, 11], edge_index=[2, 2348], edge_attr=[2348, 4], y=[64], pos=[1136, 3], name=[64], batch=[1136], ptr=[65])
#
# Step 25:
# =======
# DataBatch(x=[1179, 11], edge_index=[2, 2430], edge_attr=[2430, 4], y=[64], pos=[1179, 3], name=[64], batch=[1179], ptr=[65])
#
# Step 26:
# =======
# DataBatch(x=[1168, 11], edge_index=[2, 2420], edge_attr=[2420, 4], y=[64], pos=[1168, 3], name=[64], batch=[1168], ptr=[65])
#
# Step 27:
# =======
# DataBatch(x=[1169, 11], edge_index=[2, 2426], edge_attr=[2426, 4], y=[64], pos=[1169, 3], name=[64], batch=[1169], ptr=[65])
#
# Step 28:
# =======
# DataBatch(x=[1146, 11], edge_index=[2, 2368], edge_attr=[2368, 4], y=[64], pos=[1146, 3], name=[64], batch=[1146], ptr=[65])
#
# Step 29:
# =======
# DataBatch(x=[1124, 11], edge_index=[2, 2330], edge_attr=[2330, 4], y=[64], pos=[1124, 3], name=[64], batch=[1124], ptr=[65])
#
# Step 30:
# =======
# DataBatch(x=[1165, 11], edge_index=[2, 2406], edge_attr=[2406, 4], y=[64], pos=[1165, 3], name=[64], batch=[1165], ptr=[65])
#
# Step 31:
# =======
# DataBatch(x=[1140, 11], edge_index=[2, 2370], edge_attr=[2370, 4], y=[64], pos=[1140, 3], name=[64], batch=[1140], ptr=[65])
#
# Step 32:
# =======
# DataBatch(x=[1164, 11], edge_index=[2, 2386], edge_attr=[2386, 4], y=[64], pos=[1164, 3], name=[64], batch=[1164], ptr=[65])
#
# Step 33:
# =======
# DataBatch(x=[1183, 11], edge_index=[2, 2438], edge_attr=[2438, 4], y=[64], pos=[1183, 3], name=[64], batch=[1183], ptr=[65])
#
# Step 34:
# =======
# DataBatch(x=[1153, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1153, 3], name=[64], batch=[1153], ptr=[65])
#
# Step 35:
# =======
# DataBatch(x=[1169, 11], edge_index=[2, 2412], edge_attr=[2412, 4], y=[64], pos=[1169, 3], name=[64], batch=[1169], ptr=[65])
#
# Step 36:
# =======
# DataBatch(x=[1157, 11], edge_index=[2, 2394], edge_attr=[2394, 4], y=[64], pos=[1157, 3], name=[64], batch=[1157], ptr=[65])
#
# Step 37:
# =======
# DataBatch(x=[1140, 11], edge_index=[2, 2370], edge_attr=[2370, 4], y=[64], pos=[1140, 3], name=[64], batch=[1140], ptr=[65])
#
# Step 38:
# =======
# DataBatch(x=[1139, 11], edge_index=[2, 2328], edge_attr=[2328, 4], y=[64], pos=[1139, 3], name=[64], batch=[1139], ptr=[65])
#
# Step 39:
# =======
# DataBatch(x=[1121, 11], edge_index=[2, 2334], edge_attr=[2334, 4], y=[64], pos=[1121, 3], name=[64], batch=[1121], ptr=[65])
#
# Step 40:
# =======
# DataBatch(x=[1154, 11], edge_index=[2, 2386], edge_attr=[2386, 4], y=[64], pos=[1154, 3], name=[64], batch=[1154], ptr=[65])
#
# Step 41:
# =======
# DataBatch(x=[1151, 11], edge_index=[2, 2380], edge_attr=[2380, 4], y=[64], pos=[1151, 3], name=[64], batch=[1151], ptr=[65])
#
# Step 42:
# =======
# DataBatch(x=[1163, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1163, 3], name=[64], batch=[1163], ptr=[65])
#
# Step 43:
# =======
# DataBatch(x=[1164, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1164, 3], name=[64], batch=[1164], ptr=[65])
#
# Step 44:
# =======
# DataBatch(x=[1146, 11], edge_index=[2, 2384], edge_attr=[2384, 4], y=[64], pos=[1146, 3], name=[64], batch=[1146], ptr=[65])
#
# Step 45:
# =======
# DataBatch(x=[1116, 11], edge_index=[2, 2282], edge_attr=[2282, 4], y=[64], pos=[1116, 3], name=[64], batch=[1116], ptr=[65])
#
# Step 46:
# =======
# DataBatch(x=[1215, 11], edge_index=[2, 2490], edge_attr=[2490, 4], y=[64], pos=[1215, 3], name=[64], batch=[1215], ptr=[65])
#
# Step 47:
# =======
# DataBatch(x=[1182, 11], edge_index=[2, 2436], edge_attr=[2436, 4], y=[64], pos=[1182, 3], name=[64], batch=[1182], ptr=[65])
#
# Step 48:
# =======
# DataBatch(x=[1177, 11], edge_index=[2, 2458], edge_attr=[2458, 4], y=[64], pos=[1177, 3], name=[64], batch=[1177], ptr=[65])
#
# Step 49:
# =======
# DataBatch(x=[1129, 11], edge_index=[2, 2348], edge_attr=[2348, 4], y=[64], pos=[1129, 3], name=[64], batch=[1129], ptr=[65])
#
# Step 50:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2384], edge_attr=[2384, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 51:
# =======
# DataBatch(x=[1120, 11], edge_index=[2, 2334], edge_attr=[2334, 4], y=[64], pos=[1120, 3], name=[64], batch=[1120], ptr=[65])
#
# Step 52:
# =======
# DataBatch(x=[1152, 11], edge_index=[2, 2402], edge_attr=[2402, 4], y=[64], pos=[1152, 3], name=[64], batch=[1152], ptr=[65])
#
# Step 53:
# =======
# DataBatch(x=[1142, 11], edge_index=[2, 2368], edge_attr=[2368, 4], y=[64], pos=[1142, 3], name=[64], batch=[1142], ptr=[65])
#
# Step 54:
# =======
# DataBatch(x=[1167, 11], edge_index=[2, 2404], edge_attr=[2404, 4], y=[64], pos=[1167, 3], name=[64], batch=[1167], ptr=[65])
#
# Step 55:
# =======
# DataBatch(x=[1174, 11], edge_index=[2, 2440], edge_attr=[2440, 4], y=[64], pos=[1174, 3], name=[64], batch=[1174], ptr=[65])
#
# Step 56:
# =======
# DataBatch(x=[1165, 11], edge_index=[2, 2404], edge_attr=[2404, 4], y=[64], pos=[1165, 3], name=[64], batch=[1165], ptr=[65])
#
# Step 57:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2360], edge_attr=[2360, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 58:
# =======
# DataBatch(x=[1171, 11], edge_index=[2, 2432], edge_attr=[2432, 4], y=[64], pos=[1171, 3], name=[64], batch=[1171], ptr=[65])
#
# Step 59:
# =======
# DataBatch(x=[1112, 11], edge_index=[2, 2286], edge_attr=[2286, 4], y=[64], pos=[1112, 3], name=[64], batch=[1112], ptr=[65])
#
# Step 60:
# =======
# DataBatch(x=[1145, 11], edge_index=[2, 2376], edge_attr=[2376, 4], y=[64], pos=[1145, 3], name=[64], batch=[1145], ptr=[65])
#
# Step 61:
# =======
# DataBatch(x=[1153, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1153, 3], name=[64], batch=[1153], ptr=[65])
#
# Step 62:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2360], edge_attr=[2360, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 63:
# =======
# DataBatch(x=[1159, 11], edge_index=[2, 2402], edge_attr=[2402, 4], y=[64], pos=[1159, 3], name=[64], batch=[1159], ptr=[65])
#
# Step 64:
# =======
# DataBatch(x=[1161, 11], edge_index=[2, 2396], edge_attr=[2396, 4], y=[64], pos=[1161, 3], name=[64], batch=[1161], ptr=[65])
#
# Step 65:
# =======
# DataBatch(x=[1152, 11], edge_index=[2, 2368], edge_attr=[2368, 4], y=[64], pos=[1152, 3], name=[64], batch=[1152], ptr=[65])
#
# Step 66:
# =======
# DataBatch(x=[1167, 11], edge_index=[2, 2412], edge_attr=[2412, 4], y=[64], pos=[1167, 3], name=[64], batch=[1167], ptr=[65])
#
# Step 67:
# =======
# DataBatch(x=[1198, 11], edge_index=[2, 2502], edge_attr=[2502, 4], y=[64], pos=[1198, 3], name=[64], batch=[1198], ptr=[65])
#
# Step 68:
# =======
# DataBatch(x=[1215, 11], edge_index=[2, 2498], edge_attr=[2498, 4], y=[64], pos=[1215, 3], name=[64], batch=[1215], ptr=[65])
#
# Step 69:
# =======
# DataBatch(x=[1161, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1161, 3], name=[64], batch=[1161], ptr=[65])
#
# Step 70:
# =======
# DataBatch(x=[1135, 11], edge_index=[2, 2348], edge_attr=[2348, 4], y=[64], pos=[1135, 3], name=[64], batch=[1135], ptr=[65])
#
# Step 71:
# =======
# DataBatch(x=[1132, 11], edge_index=[2, 2350], edge_attr=[2350, 4], y=[64], pos=[1132, 3], name=[64], batch=[1132], ptr=[65])
#
# Step 72:
# =======
# DataBatch(x=[1159, 11], edge_index=[2, 2382], edge_attr=[2382, 4], y=[64], pos=[1159, 3], name=[64], batch=[1159], ptr=[65])
#
# Step 73:
# =======
# DataBatch(x=[1147, 11], edge_index=[2, 2358], edge_attr=[2358, 4], y=[64], pos=[1147, 3], name=[64], batch=[1147], ptr=[65])
#
# Step 74:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2336], edge_attr=[2336, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 75:
# =======
# DataBatch(x=[1162, 11], edge_index=[2, 2402], edge_attr=[2402, 4], y=[64], pos=[1162, 3], name=[64], batch=[1162], ptr=[65])
#
# Step 76:
# =======
# DataBatch(x=[1162, 11], edge_index=[2, 2414], edge_attr=[2414, 4], y=[64], pos=[1162, 3], name=[64], batch=[1162], ptr=[65])
#
# Step 77:
# =======
# DataBatch(x=[1153, 11], edge_index=[2, 2382], edge_attr=[2382, 4], y=[64], pos=[1153, 3], name=[64], batch=[1153], ptr=[65])
#
# Step 78:
# =======
# DataBatch(x=[1161, 11], edge_index=[2, 2424], edge_attr=[2424, 4], y=[64], pos=[1161, 3], name=[64], batch=[1161], ptr=[65])
#
# Step 79:
# =======
# DataBatch(x=[1167, 11], edge_index=[2, 2424], edge_attr=[2424, 4], y=[64], pos=[1167, 3], name=[64], batch=[1167], ptr=[65])
#
# Step 80:
# =======
# DataBatch(x=[1138, 11], edge_index=[2, 2374], edge_attr=[2374, 4], y=[64], pos=[1138, 3], name=[64], batch=[1138], ptr=[65])
#
# Step 81:
# =======
# DataBatch(x=[1134, 11], edge_index=[2, 2330], edge_attr=[2330, 4], y=[64], pos=[1134, 3], name=[64], batch=[1134], ptr=[65])
#
# Step 82:
# =======
# DataBatch(x=[1141, 11], edge_index=[2, 2348], edge_attr=[2348, 4], y=[64], pos=[1141, 3], name=[64], batch=[1141], ptr=[65])
#
# Step 83:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2330], edge_attr=[2330, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 84:
# =======
# DataBatch(x=[1172, 11], edge_index=[2, 2424], edge_attr=[2424, 4], y=[64], pos=[1172, 3], name=[64], batch=[1172], ptr=[65])
#
# Step 85:
# =======
# DataBatch(x=[1155, 11], edge_index=[2, 2388], edge_attr=[2388, 4], y=[64], pos=[1155, 3], name=[64], batch=[1155], ptr=[65])
#
# Step 86:
# =======
# DataBatch(x=[1191, 11], edge_index=[2, 2460], edge_attr=[2460, 4], y=[64], pos=[1191, 3], name=[64], batch=[1191], ptr=[65])
#
# Step 87:
# =======
# DataBatch(x=[1147, 11], edge_index=[2, 2356], edge_attr=[2356, 4], y=[64], pos=[1147, 3], name=[64], batch=[1147], ptr=[65])
#
# Step 88:
# =======
# DataBatch(x=[1145, 11], edge_index=[2, 2376], edge_attr=[2376, 4], y=[64], pos=[1145, 3], name=[64], batch=[1145], ptr=[65])
#
# Step 89:
# =======
# DataBatch(x=[1140, 11], edge_index=[2, 2396], edge_attr=[2396, 4], y=[64], pos=[1140, 3], name=[64], batch=[1140], ptr=[65])
#
# Step 90:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2386], edge_attr=[2386, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 91:
# =======
# DataBatch(x=[1156, 11], edge_index=[2, 2378], edge_attr=[2378, 4], y=[64], pos=[1156, 3], name=[64], batch=[1156], ptr=[65])
#
# Step 92:
# =======
# DataBatch(x=[1164, 11], edge_index=[2, 2380], edge_attr=[2380, 4], y=[64], pos=[1164, 3], name=[64], batch=[1164], ptr=[65])
#
# Step 93:
# =======
# DataBatch(x=[1160, 11], edge_index=[2, 2394], edge_attr=[2394, 4], y=[64], pos=[1160, 3], name=[64], batch=[1160], ptr=[65])
#
# Step 94:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2364], edge_attr=[2364, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 95:
# =======
# DataBatch(x=[1099, 11], edge_index=[2, 2242], edge_attr=[2242, 4], y=[64], pos=[1099, 3], name=[64], batch=[1099], ptr=[65])
#
# Step 96:
# =======
# DataBatch(x=[1168, 11], edge_index=[2, 2378], edge_attr=[2378, 4], y=[64], pos=[1168, 3], name=[64], batch=[1168], ptr=[65])
#
# Step 97:
# =======
# DataBatch(x=[1141, 11], edge_index=[2, 2344], edge_attr=[2344, 4], y=[64], pos=[1141, 3], name=[64], batch=[1141], ptr=[65])
#
# Step 98:
# =======
# DataBatch(x=[1133, 11], edge_index=[2, 2322], edge_attr=[2322, 4], y=[64], pos=[1133, 3], name=[64], batch=[1133], ptr=[65])
#
# Step 99:
# =======
# DataBatch(x=[1141, 11], edge_index=[2, 2376], edge_attr=[2376, 4], y=[64], pos=[1141, 3], name=[64], batch=[1141], ptr=[65])
#
# Step 100:
# =======
# DataBatch(x=[1165, 11], edge_index=[2, 2426], edge_attr=[2426, 4], y=[64], pos=[1165, 3], name=[64], batch=[1165], ptr=[65])
#
# Step 101:
# =======
# DataBatch(x=[1141, 11], edge_index=[2, 2366], edge_attr=[2366, 4], y=[64], pos=[1141, 3], name=[64], batch=[1141], ptr=[65])
#
# Step 102:
# =======
# DataBatch(x=[1164, 11], edge_index=[2, 2384], edge_attr=[2384, 4], y=[64], pos=[1164, 3], name=[64], batch=[1164], ptr=[65])
#
# Step 103:
# =======
# DataBatch(x=[1171, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1171, 3], name=[64], batch=[1171], ptr=[65])
#
# Step 104:
# =======
# DataBatch(x=[1141, 11], edge_index=[2, 2346], edge_attr=[2346, 4], y=[64], pos=[1141, 3], name=[64], batch=[1141], ptr=[65])
#
# Step 105:
# =======
# DataBatch(x=[1203, 11], edge_index=[2, 2470], edge_attr=[2470, 4], y=[64], pos=[1203, 3], name=[64], batch=[1203], ptr=[65])
#
# Step 106:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2334], edge_attr=[2334, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 107:
# =======
# DataBatch(x=[1156, 11], edge_index=[2, 2394], edge_attr=[2394, 4], y=[64], pos=[1156, 3], name=[64], batch=[1156], ptr=[65])
#
# Step 108:
# =======
# DataBatch(x=[1154, 11], edge_index=[2, 2374], edge_attr=[2374, 4], y=[64], pos=[1154, 3], name=[64], batch=[1154], ptr=[65])
#
# Step 109:
# =======
# DataBatch(x=[1185, 11], edge_index=[2, 2448], edge_attr=[2448, 4], y=[64], pos=[1185, 3], name=[64], batch=[1185], ptr=[65])
#
# Step 110:
# =======
# DataBatch(x=[1148, 11], edge_index=[2, 2390], edge_attr=[2390, 4], y=[64], pos=[1148, 3], name=[64], batch=[1148], ptr=[65])
#
# Step 111:
# =======
# DataBatch(x=[1151, 11], edge_index=[2, 2382], edge_attr=[2382, 4], y=[64], pos=[1151, 3], name=[64], batch=[1151], ptr=[65])
#
# Step 112:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2348], edge_attr=[2348, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 113:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 114:
# =======
# DataBatch(x=[1186, 11], edge_index=[2, 2464], edge_attr=[2464, 4], y=[64], pos=[1186, 3], name=[64], batch=[1186], ptr=[65])
#
# Step 115:
# =======
# DataBatch(x=[1142, 11], edge_index=[2, 2342], edge_attr=[2342, 4], y=[64], pos=[1142, 3], name=[64], batch=[1142], ptr=[65])
#
# Step 116:
# =======
# DataBatch(x=[1132, 11], edge_index=[2, 2342], edge_attr=[2342, 4], y=[64], pos=[1132, 3], name=[64], batch=[1132], ptr=[65])
#
# Step 117:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2402], edge_attr=[2402, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 118:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2380], edge_attr=[2380, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 119:
# =======
# DataBatch(x=[1153, 11], edge_index=[2, 2378], edge_attr=[2378, 4], y=[64], pos=[1153, 3], name=[64], batch=[1153], ptr=[65])
#
# Step 120:
# =======
# DataBatch(x=[1182, 11], edge_index=[2, 2440], edge_attr=[2440, 4], y=[64], pos=[1182, 3], name=[64], batch=[1182], ptr=[65])
#
# Step 121:
# =======
# DataBatch(x=[1135, 11], edge_index=[2, 2330], edge_attr=[2330, 4], y=[64], pos=[1135, 3], name=[64], batch=[1135], ptr=[65])
#
# Step 122:
# =======
# DataBatch(x=[1132, 11], edge_index=[2, 2322], edge_attr=[2322, 4], y=[64], pos=[1132, 3], name=[64], batch=[1132], ptr=[65])
#
# Step 123:
# =======
# DataBatch(x=[1194, 11], edge_index=[2, 2434], edge_attr=[2434, 4], y=[64], pos=[1194, 3], name=[64], batch=[1194], ptr=[65])
#
# Step 124:
# =======
# DataBatch(x=[1166, 11], edge_index=[2, 2416], edge_attr=[2416, 4], y=[64], pos=[1166, 3], name=[64], batch=[1166], ptr=[65])
#
# Step 125:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2400], edge_attr=[2400, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 126:
# =======
# DataBatch(x=[1174, 11], edge_index=[2, 2468], edge_attr=[2468, 4], y=[64], pos=[1174, 3], name=[64], batch=[1174], ptr=[65])
#
# Step 127:
# =======
# DataBatch(x=[1164, 11], edge_index=[2, 2402], edge_attr=[2402, 4], y=[64], pos=[1164, 3], name=[64], batch=[1164], ptr=[65])
#
# Step 128:
# =======
# DataBatch(x=[1178, 11], edge_index=[2, 2438], edge_attr=[2438, 4], y=[64], pos=[1178, 3], name=[64], batch=[1178], ptr=[65])
#
# Step 129:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2404], edge_attr=[2404, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 130:
# =======
# DataBatch(x=[1191, 11], edge_index=[2, 2472], edge_attr=[2472, 4], y=[64], pos=[1191, 3], name=[64], batch=[1191], ptr=[65])
#
# Step 131:
# =======
# DataBatch(x=[1142, 11], edge_index=[2, 2346], edge_attr=[2346, 4], y=[64], pos=[1142, 3], name=[64], batch=[1142], ptr=[65])
#
# Step 132:
# =======
# DataBatch(x=[1126, 11], edge_index=[2, 2322], edge_attr=[2322, 4], y=[64], pos=[1126, 3], name=[64], batch=[1126], ptr=[65])
#
# Step 133:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2330], edge_attr=[2330, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 134:
# =======
# DataBatch(x=[1147, 11], edge_index=[2, 2372], edge_attr=[2372, 4], y=[64], pos=[1147, 3], name=[64], batch=[1147], ptr=[65])
#
# Step 135:
# =======
# DataBatch(x=[1149, 11], edge_index=[2, 2384], edge_attr=[2384, 4], y=[64], pos=[1149, 3], name=[64], batch=[1149], ptr=[65])
#
# Step 136:
# =======
# DataBatch(x=[1168, 11], edge_index=[2, 2430], edge_attr=[2430, 4], y=[64], pos=[1168, 3], name=[64], batch=[1168], ptr=[65])
#
# Step 137:
# =======
# DataBatch(x=[1161, 11], edge_index=[2, 2396], edge_attr=[2396, 4], y=[64], pos=[1161, 3], name=[64], batch=[1161], ptr=[65])
#
# Step 138:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2368], edge_attr=[2368, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 139:
# =======
# DataBatch(x=[1172, 11], edge_index=[2, 2414], edge_attr=[2414, 4], y=[64], pos=[1172, 3], name=[64], batch=[1172], ptr=[65])
#
# Step 140:
# =======
# DataBatch(x=[1167, 11], edge_index=[2, 2416], edge_attr=[2416, 4], y=[64], pos=[1167, 3], name=[64], batch=[1167], ptr=[65])
#
# Step 141:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 142:
# =======
# DataBatch(x=[1163, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1163, 3], name=[64], batch=[1163], ptr=[65])
#
# Step 143:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 144:
# =======
# DataBatch(x=[1125, 11], edge_index=[2, 2328], edge_attr=[2328, 4], y=[64], pos=[1125, 3], name=[64], batch=[1125], ptr=[65])
#
# Step 145:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2364], edge_attr=[2364, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 146:
# =======
# DataBatch(x=[1163, 11], edge_index=[2, 2390], edge_attr=[2390, 4], y=[64], pos=[1163, 3], name=[64], batch=[1163], ptr=[65])
#
# Step 147:
# =======
# DataBatch(x=[1185, 11], edge_index=[2, 2442], edge_attr=[2442, 4], y=[64], pos=[1185, 3], name=[64], batch=[1185], ptr=[65])
#
# Step 148:
# =======
# DataBatch(x=[1181, 11], edge_index=[2, 2452], edge_attr=[2452, 4], y=[64], pos=[1181, 3], name=[64], batch=[1181], ptr=[65])
#
# Step 149:
# =======
# DataBatch(x=[1176, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1176, 3], name=[64], batch=[1176], ptr=[65])
#
# Step 150:
# =======
# DataBatch(x=[1145, 11], edge_index=[2, 2372], edge_attr=[2372, 4], y=[64], pos=[1145, 3], name=[64], batch=[1145], ptr=[65])
#
# Step 151:
# =======
# DataBatch(x=[1106, 11], edge_index=[2, 2302], edge_attr=[2302, 4], y=[64], pos=[1106, 3], name=[64], batch=[1106], ptr=[65])
#
# Step 152:
# =======
# DataBatch(x=[1151, 11], edge_index=[2, 2384], edge_attr=[2384, 4], y=[64], pos=[1151, 3], name=[64], batch=[1151], ptr=[65])
#
# Step 153:
# =======
# DataBatch(x=[1192, 11], edge_index=[2, 2446], edge_attr=[2446, 4], y=[64], pos=[1192, 3], name=[64], batch=[1192], ptr=[65])
#
# Step 154:
# =======
# DataBatch(x=[1153, 11], edge_index=[2, 2344], edge_attr=[2344, 4], y=[64], pos=[1153, 3], name=[64], batch=[1153], ptr=[65])
#
# Step 155:
# =======
# DataBatch(x=[1161, 11], edge_index=[2, 2380], edge_attr=[2380, 4], y=[64], pos=[1161, 3], name=[64], batch=[1161], ptr=[65])
#
# Step 156:
# =======
# DataBatch(x=[1168, 11], edge_index=[2, 2406], edge_attr=[2406, 4], y=[64], pos=[1168, 3], name=[64], batch=[1168], ptr=[65])
#
# Step 157:
# =======
# DataBatch(x=[1130, 11], edge_index=[2, 2318], edge_attr=[2318, 4], y=[64], pos=[1130, 3], name=[64], batch=[1130], ptr=[65])
#
# Step 158:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2352], edge_attr=[2352, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 159:
# =======
# DataBatch(x=[1127, 11], edge_index=[2, 2314], edge_attr=[2314, 4], y=[64], pos=[1127, 3], name=[64], batch=[1127], ptr=[65])
#
# Step 160:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 161:
# =======
# DataBatch(x=[1156, 11], edge_index=[2, 2412], edge_attr=[2412, 4], y=[64], pos=[1156, 3], name=[64], batch=[1156], ptr=[65])
#
# Step 162:
# =======
# DataBatch(x=[1165, 11], edge_index=[2, 2424], edge_attr=[2424, 4], y=[64], pos=[1165, 3], name=[64], batch=[1165], ptr=[65])
#
# Step 163:
# =======
# DataBatch(x=[1127, 11], edge_index=[2, 2340], edge_attr=[2340, 4], y=[64], pos=[1127, 3], name=[64], batch=[1127], ptr=[65])
#
# Step 164:
# =======
# DataBatch(x=[1172, 11], edge_index=[2, 2426], edge_attr=[2426, 4], y=[64], pos=[1172, 3], name=[64], batch=[1172], ptr=[65])
#
# Step 165:
# =======
# DataBatch(x=[1124, 11], edge_index=[2, 2352], edge_attr=[2352, 4], y=[64], pos=[1124, 3], name=[64], batch=[1124], ptr=[65])
#
# Step 166:
# =======
# DataBatch(x=[1113, 11], edge_index=[2, 2280], edge_attr=[2280, 4], y=[64], pos=[1113, 3], name=[64], batch=[1113], ptr=[65])
#
# Step 167:
# =======
# DataBatch(x=[1203, 11], edge_index=[2, 2466], edge_attr=[2466, 4], y=[64], pos=[1203, 3], name=[64], batch=[1203], ptr=[65])
#
# Step 168:
# =======
# DataBatch(x=[1145, 11], edge_index=[2, 2344], edge_attr=[2344, 4], y=[64], pos=[1145, 3], name=[64], batch=[1145], ptr=[65])
#
# Step 169:
# =======
# DataBatch(x=[1172, 11], edge_index=[2, 2410], edge_attr=[2410, 4], y=[64], pos=[1172, 3], name=[64], batch=[1172], ptr=[65])
#
# Step 170:
# =======
# DataBatch(x=[1171, 11], edge_index=[2, 2396], edge_attr=[2396, 4], y=[64], pos=[1171, 3], name=[64], batch=[1171], ptr=[65])
#
# Step 171:
# =======
# DataBatch(x=[1135, 11], edge_index=[2, 2340], edge_attr=[2340, 4], y=[64], pos=[1135, 3], name=[64], batch=[1135], ptr=[65])
#
# Step 172:
# =======
# DataBatch(x=[1114, 11], edge_index=[2, 2316], edge_attr=[2316, 4], y=[64], pos=[1114, 3], name=[64], batch=[1114], ptr=[65])
#
# Step 173:
# =======
# DataBatch(x=[1132, 11], edge_index=[2, 2364], edge_attr=[2364, 4], y=[64], pos=[1132, 3], name=[64], batch=[1132], ptr=[65])
#
# Step 174:
# =======
# DataBatch(x=[1142, 11], edge_index=[2, 2344], edge_attr=[2344, 4], y=[64], pos=[1142, 3], name=[64], batch=[1142], ptr=[65])
#
# Step 175:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2378], edge_attr=[2378, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 176:
# =======
# DataBatch(x=[1122, 11], edge_index=[2, 2334], edge_attr=[2334, 4], y=[64], pos=[1122, 3], name=[64], batch=[1122], ptr=[65])
#
# Step 177:
# =======
# DataBatch(x=[1155, 11], edge_index=[2, 2398], edge_attr=[2398, 4], y=[64], pos=[1155, 3], name=[64], batch=[1155], ptr=[65])
#
# Step 178:
# =======
# DataBatch(x=[1166, 11], edge_index=[2, 2404], edge_attr=[2404, 4], y=[64], pos=[1166, 3], name=[64], batch=[1166], ptr=[65])
#
# Step 179:
# =======
# DataBatch(x=[1111, 11], edge_index=[2, 2304], edge_attr=[2304, 4], y=[64], pos=[1111, 3], name=[64], batch=[1111], ptr=[65])
#
# Step 180:
# =======
# DataBatch(x=[1141, 11], edge_index=[2, 2370], edge_attr=[2370, 4], y=[64], pos=[1141, 3], name=[64], batch=[1141], ptr=[65])
#
# Step 181:
# =======
# DataBatch(x=[1156, 11], edge_index=[2, 2370], edge_attr=[2370, 4], y=[64], pos=[1156, 3], name=[64], batch=[1156], ptr=[65])
#
# Step 182:
# =======
# DataBatch(x=[1199, 11], edge_index=[2, 2486], edge_attr=[2486, 4], y=[64], pos=[1199, 3], name=[64], batch=[1199], ptr=[65])
#
# Step 183:
# =======
# DataBatch(x=[1171, 11], edge_index=[2, 2434], edge_attr=[2434, 4], y=[64], pos=[1171, 3], name=[64], batch=[1171], ptr=[65])
#
# Step 184:
# =======
# DataBatch(x=[1133, 11], edge_index=[2, 2326], edge_attr=[2326, 4], y=[64], pos=[1133, 3], name=[64], batch=[1133], ptr=[65])
#
# Step 185:
# =======
# DataBatch(x=[1161, 11], edge_index=[2, 2436], edge_attr=[2436, 4], y=[64], pos=[1161, 3], name=[64], batch=[1161], ptr=[65])
#
# Step 186:
# =======
# DataBatch(x=[1152, 11], edge_index=[2, 2388], edge_attr=[2388, 4], y=[64], pos=[1152, 3], name=[64], batch=[1152], ptr=[65])
#
# Step 187:
# =======
# DataBatch(x=[1133, 11], edge_index=[2, 2334], edge_attr=[2334, 4], y=[64], pos=[1133, 3], name=[64], batch=[1133], ptr=[65])
#
# Step 188:
# =======
# DataBatch(x=[1168, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1168, 3], name=[64], batch=[1168], ptr=[65])
#
# Step 189:
# =======
# DataBatch(x=[1151, 11], edge_index=[2, 2352], edge_attr=[2352, 4], y=[64], pos=[1151, 3], name=[64], batch=[1151], ptr=[65])
#
# Step 190:
# =======
# DataBatch(x=[1145, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1145, 3], name=[64], batch=[1145], ptr=[65])
#
# Step 191:
# =======
# DataBatch(x=[1162, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1162, 3], name=[64], batch=[1162], ptr=[65])
#
# Step 192:
# =======
# DataBatch(x=[1116, 11], edge_index=[2, 2318], edge_attr=[2318, 4], y=[64], pos=[1116, 3], name=[64], batch=[1116], ptr=[65])
#
# Step 193:
# =======
# DataBatch(x=[1175, 11], edge_index=[2, 2436], edge_attr=[2436, 4], y=[64], pos=[1175, 3], name=[64], batch=[1175], ptr=[65])
#
# Step 194:
# =======
# DataBatch(x=[1106, 11], edge_index=[2, 2280], edge_attr=[2280, 4], y=[64], pos=[1106, 3], name=[64], batch=[1106], ptr=[65])
#
# Step 195:
# =======
# DataBatch(x=[1173, 11], edge_index=[2, 2442], edge_attr=[2442, 4], y=[64], pos=[1173, 3], name=[64], batch=[1173], ptr=[65])
#
# Step 196:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2386], edge_attr=[2386, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 197:
# =======
# DataBatch(x=[1150, 11], edge_index=[2, 2360], edge_attr=[2360, 4], y=[64], pos=[1150, 3], name=[64], batch=[1150], ptr=[65])
#
# Step 198:
# =======
# DataBatch(x=[1126, 11], edge_index=[2, 2324], edge_attr=[2324, 4], y=[64], pos=[1126, 3], name=[64], batch=[1126], ptr=[65])
#
# Step 199:
# =======
# DataBatch(x=[1148, 11], edge_index=[2, 2358], edge_attr=[2358, 4], y=[64], pos=[1148, 3], name=[64], batch=[1148], ptr=[65])
#
# Step 200:
# =======
# DataBatch(x=[1165, 11], edge_index=[2, 2410], edge_attr=[2410, 4], y=[64], pos=[1165, 3], name=[64], batch=[1165], ptr=[65])
#
# Step 201:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2372], edge_attr=[2372, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 202:
# =======
# DataBatch(x=[1182, 11], edge_index=[2, 2444], edge_attr=[2444, 4], y=[64], pos=[1182, 3], name=[64], batch=[1182], ptr=[65])
#
# Step 203:
# =======
# DataBatch(x=[1118, 11], edge_index=[2, 2324], edge_attr=[2324, 4], y=[64], pos=[1118, 3], name=[64], batch=[1118], ptr=[65])
#
# Step 204:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2392], edge_attr=[2392, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 205:
# =======
# DataBatch(x=[1130, 11], edge_index=[2, 2330], edge_attr=[2330, 4], y=[64], pos=[1130, 3], name=[64], batch=[1130], ptr=[65])
#
# Step 206:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2386], edge_attr=[2386, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 207:
# =======
# DataBatch(x=[1126, 11], edge_index=[2, 2346], edge_attr=[2346, 4], y=[64], pos=[1126, 3], name=[64], batch=[1126], ptr=[65])
#
# Step 208:
# =======
# DataBatch(x=[1131, 11], edge_index=[2, 2340], edge_attr=[2340, 4], y=[64], pos=[1131, 3], name=[64], batch=[1131], ptr=[65])
#
# Step 209:
# =======
# DataBatch(x=[1132, 11], edge_index=[2, 2326], edge_attr=[2326, 4], y=[64], pos=[1132, 3], name=[64], batch=[1132], ptr=[65])
#
# Step 210:
# =======
# DataBatch(x=[1182, 11], edge_index=[2, 2440], edge_attr=[2440, 4], y=[64], pos=[1182, 3], name=[64], batch=[1182], ptr=[65])
#
# Step 211:
# =======
# DataBatch(x=[1147, 11], edge_index=[2, 2344], edge_attr=[2344, 4], y=[64], pos=[1147, 3], name=[64], batch=[1147], ptr=[65])
#
# Step 212:
# =======
# DataBatch(x=[1120, 11], edge_index=[2, 2310], edge_attr=[2310, 4], y=[64], pos=[1120, 3], name=[64], batch=[1120], ptr=[65])
#
# Step 213:
# =======
# DataBatch(x=[1159, 11], edge_index=[2, 2394], edge_attr=[2394, 4], y=[64], pos=[1159, 3], name=[64], batch=[1159], ptr=[65])
#
# Step 214:
# =======
# DataBatch(x=[1160, 11], edge_index=[2, 2372], edge_attr=[2372, 4], y=[64], pos=[1160, 3], name=[64], batch=[1160], ptr=[65])
#
# Step 215:
# =======
# DataBatch(x=[1163, 11], edge_index=[2, 2396], edge_attr=[2396, 4], y=[64], pos=[1163, 3], name=[64], batch=[1163], ptr=[65])
#
# Step 216:
# =======
# DataBatch(x=[1142, 11], edge_index=[2, 2372], edge_attr=[2372, 4], y=[64], pos=[1142, 3], name=[64], batch=[1142], ptr=[65])
#
# Step 217:
# =======
# DataBatch(x=[1159, 11], edge_index=[2, 2404], edge_attr=[2404, 4], y=[64], pos=[1159, 3], name=[64], batch=[1159], ptr=[65])
#
# Step 218:
# =======
# DataBatch(x=[1146, 11], edge_index=[2, 2374], edge_attr=[2374, 4], y=[64], pos=[1146, 3], name=[64], batch=[1146], ptr=[65])
#
# Step 219:
# =======
# DataBatch(x=[1154, 11], edge_index=[2, 2378], edge_attr=[2378, 4], y=[64], pos=[1154, 3], name=[64], batch=[1154], ptr=[65])
#
# Step 220:
# =======
# DataBatch(x=[1140, 11], edge_index=[2, 2360], edge_attr=[2360, 4], y=[64], pos=[1140, 3], name=[64], batch=[1140], ptr=[65])
#
# Step 221:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2344], edge_attr=[2344, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 222:
# =======
# DataBatch(x=[1162, 11], edge_index=[2, 2386], edge_attr=[2386, 4], y=[64], pos=[1162, 3], name=[64], batch=[1162], ptr=[65])
#
# Step 223:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2352], edge_attr=[2352, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 224:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2346], edge_attr=[2346, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 225:
# =======
# DataBatch(x=[1129, 11], edge_index=[2, 2334], edge_attr=[2334, 4], y=[64], pos=[1129, 3], name=[64], batch=[1129], ptr=[65])
#
# Step 226:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2358], edge_attr=[2358, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 227:
# =======
# DataBatch(x=[1207, 11], edge_index=[2, 2498], edge_attr=[2498, 4], y=[64], pos=[1207, 3], name=[64], batch=[1207], ptr=[65])
#
# Step 228:
# =======
# DataBatch(x=[1101, 11], edge_index=[2, 2286], edge_attr=[2286, 4], y=[64], pos=[1101, 3], name=[64], batch=[1101], ptr=[65])
#
# Step 229:
# =======
# DataBatch(x=[1153, 11], edge_index=[2, 2380], edge_attr=[2380, 4], y=[64], pos=[1153, 3], name=[64], batch=[1153], ptr=[65])
#
# Step 230:
# =======
# DataBatch(x=[1153, 11], edge_index=[2, 2382], edge_attr=[2382, 4], y=[64], pos=[1153, 3], name=[64], batch=[1153], ptr=[65])
#
# Step 231:
# =======
# DataBatch(x=[1160, 11], edge_index=[2, 2398], edge_attr=[2398, 4], y=[64], pos=[1160, 3], name=[64], batch=[1160], ptr=[65])
#
# Step 232:
# =======
# DataBatch(x=[1181, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1181, 3], name=[64], batch=[1181], ptr=[65])
#
# Step 233:
# =======
# DataBatch(x=[1124, 11], edge_index=[2, 2332], edge_attr=[2332, 4], y=[64], pos=[1124, 3], name=[64], batch=[1124], ptr=[65])
#
# Step 234:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2346], edge_attr=[2346, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 235:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2368], edge_attr=[2368, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 236:
# =======
# DataBatch(x=[1157, 11], edge_index=[2, 2388], edge_attr=[2388, 4], y=[64], pos=[1157, 3], name=[64], batch=[1157], ptr=[65])
#
# Step 237:
# =======
# DataBatch(x=[1164, 11], edge_index=[2, 2422], edge_attr=[2422, 4], y=[64], pos=[1164, 3], name=[64], batch=[1164], ptr=[65])
#
# Step 238:
# =======
# DataBatch(x=[1176, 11], edge_index=[2, 2430], edge_attr=[2430, 4], y=[64], pos=[1176, 3], name=[64], batch=[1176], ptr=[65])
#
# Step 239:
# =======
# DataBatch(x=[1158, 11], edge_index=[2, 2376], edge_attr=[2376, 4], y=[64], pos=[1158, 3], name=[64], batch=[1158], ptr=[65])
#
# Step 240:
# =======
# DataBatch(x=[1138, 11], edge_index=[2, 2348], edge_attr=[2348, 4], y=[64], pos=[1138, 3], name=[64], batch=[1138], ptr=[65])
#
# Step 241:
# =======
# DataBatch(x=[1186, 11], edge_index=[2, 2470], edge_attr=[2470, 4], y=[64], pos=[1186, 3], name=[64], batch=[1186], ptr=[65])
#
# Step 242:
# =======
# DataBatch(x=[1147, 11], edge_index=[2, 2370], edge_attr=[2370, 4], y=[64], pos=[1147, 3], name=[64], batch=[1147], ptr=[65])
#
# Step 243:
# =======
# DataBatch(x=[1178, 11], edge_index=[2, 2432], edge_attr=[2432, 4], y=[64], pos=[1178, 3], name=[64], batch=[1178], ptr=[65])
#
# Step 244:
# =======
# DataBatch(x=[1138, 11], edge_index=[2, 2362], edge_attr=[2362, 4], y=[64], pos=[1138, 3], name=[64], batch=[1138], ptr=[65])
#
# Step 245:
# =======
# DataBatch(x=[1118, 11], edge_index=[2, 2302], edge_attr=[2302, 4], y=[64], pos=[1118, 3], name=[64], batch=[1118], ptr=[65])
#
# Step 246:
# =======
# DataBatch(x=[1123, 11], edge_index=[2, 2314], edge_attr=[2314, 4], y=[64], pos=[1123, 3], name=[64], batch=[1123], ptr=[65])
#
# Step 247:
# =======
# DataBatch(x=[1157, 11], edge_index=[2, 2424], edge_attr=[2424, 4], y=[64], pos=[1157, 3], name=[64], batch=[1157], ptr=[65])
#
# Step 248:
# =======
# DataBatch(x=[1156, 11], edge_index=[2, 2408], edge_attr=[2408, 4], y=[64], pos=[1156, 3], name=[64], batch=[1156], ptr=[65])
#
# Step 249:
# =======
# DataBatch(x=[1174, 11], edge_index=[2, 2442], edge_attr=[2442, 4], y=[64], pos=[1174, 3], name=[64], batch=[1174], ptr=[65])
#
# Step 250:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2352], edge_attr=[2352, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 251:
# =======
# DataBatch(x=[1121, 11], edge_index=[2, 2316], edge_attr=[2316, 4], y=[64], pos=[1121, 3], name=[64], batch=[1121], ptr=[65])
#
# Step 252:
# =======
# DataBatch(x=[1232, 11], edge_index=[2, 2550], edge_attr=[2550, 4], y=[64], pos=[1232, 3], name=[64], batch=[1232], ptr=[65])
#
# Step 253:
# =======
# DataBatch(x=[1116, 11], edge_index=[2, 2288], edge_attr=[2288, 4], y=[64], pos=[1116, 3], name=[64], batch=[1116], ptr=[65])
#
# Step 254:
# =======
# DataBatch(x=[1093, 11], edge_index=[2, 2262], edge_attr=[2262, 4], y=[64], pos=[1093, 3], name=[64], batch=[1093], ptr=[65])
#
# Step 255:
# =======
# DataBatch(x=[1152, 11], edge_index=[2, 2356], edge_attr=[2356, 4], y=[64], pos=[1152, 3], name=[64], batch=[1152], ptr=[65])
#
# Step 256:
# =======
# DataBatch(x=[1106, 11], edge_index=[2, 2294], edge_attr=[2294, 4], y=[64], pos=[1106, 3], name=[64], batch=[1106], ptr=[65])
#
# Step 257:
# =======
# DataBatch(x=[1149, 11], edge_index=[2, 2376], edge_attr=[2376, 4], y=[64], pos=[1149, 3], name=[64], batch=[1149], ptr=[65])
#
# Step 258:
# =======
# DataBatch(x=[1149, 11], edge_index=[2, 2358], edge_attr=[2358, 4], y=[64], pos=[1149, 3], name=[64], batch=[1149], ptr=[65])
#
# Step 259:
# =======
# DataBatch(x=[1142, 11], edge_index=[2, 2362], edge_attr=[2362, 4], y=[64], pos=[1142, 3], name=[64], batch=[1142], ptr=[65])
#
# Step 260:
# =======
# DataBatch(x=[1130, 11], edge_index=[2, 2324], edge_attr=[2324, 4], y=[64], pos=[1130, 3], name=[64], batch=[1130], ptr=[65])
#
# Step 261:
# =======
# DataBatch(x=[1137, 11], edge_index=[2, 2356], edge_attr=[2356, 4], y=[64], pos=[1137, 3], name=[64], batch=[1137], ptr=[65])
#
# Step 262:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2354], edge_attr=[2354, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 263:
# =======
# DataBatch(x=[1162, 11], edge_index=[2, 2412], edge_attr=[2412, 4], y=[64], pos=[1162, 3], name=[64], batch=[1162], ptr=[65])
#
# Step 264:
# =======
# DataBatch(x=[1210, 11], edge_index=[2, 2498], edge_attr=[2498, 4], y=[64], pos=[1210, 3], name=[64], batch=[1210], ptr=[65])
#
# Step 265:
# =======
# DataBatch(x=[1169, 11], edge_index=[2, 2406], edge_attr=[2406, 4], y=[64], pos=[1169, 3], name=[64], batch=[1169], ptr=[65])
#
# Step 266:
# =======
# DataBatch(x=[1117, 11], edge_index=[2, 2326], edge_attr=[2326, 4], y=[64], pos=[1117, 3], name=[64], batch=[1117], ptr=[65])
#
# Step 267:
# =======
# DataBatch(x=[1161, 11], edge_index=[2, 2390], edge_attr=[2390, 4], y=[64], pos=[1161, 3], name=[64], batch=[1161], ptr=[65])
#
# Step 268:
# =======
# DataBatch(x=[1153, 11], edge_index=[2, 2370], edge_attr=[2370, 4], y=[64], pos=[1153, 3], name=[64], batch=[1153], ptr=[65])
#
# Step 269:
# =======
# DataBatch(x=[1160, 11], edge_index=[2, 2400], edge_attr=[2400, 4], y=[64], pos=[1160, 3], name=[64], batch=[1160], ptr=[65])
#
# Step 270:
# =======
# DataBatch(x=[1164, 11], edge_index=[2, 2416], edge_attr=[2416, 4], y=[64], pos=[1164, 3], name=[64], batch=[1164], ptr=[65])
#
# Step 271:
# =======
# DataBatch(x=[1182, 11], edge_index=[2, 2438], edge_attr=[2438, 4], y=[64], pos=[1182, 3], name=[64], batch=[1182], ptr=[65])
#
# Step 272:
# =======
# DataBatch(x=[1169, 11], edge_index=[2, 2404], edge_attr=[2404, 4], y=[64], pos=[1169, 3], name=[64], batch=[1169], ptr=[65])
#
# Step 273:
# =======
# DataBatch(x=[1164, 11], edge_index=[2, 2418], edge_attr=[2418, 4], y=[64], pos=[1164, 3], name=[64], batch=[1164], ptr=[65])
#
# Step 274:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2350], edge_attr=[2350, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 275:
# =======
# DataBatch(x=[1183, 11], edge_index=[2, 2444], edge_attr=[2444, 4], y=[64], pos=[1183, 3], name=[64], batch=[1183], ptr=[65])
#
# Step 276:
# =======
# DataBatch(x=[1125, 11], edge_index=[2, 2322], edge_attr=[2322, 4], y=[64], pos=[1125, 3], name=[64], batch=[1125], ptr=[65])
#
# Step 277:
# =======
# DataBatch(x=[1148, 11], edge_index=[2, 2370], edge_attr=[2370, 4], y=[64], pos=[1148, 3], name=[64], batch=[1148], ptr=[65])
#
# Step 278:
# =======
# DataBatch(x=[1157, 11], edge_index=[2, 2416], edge_attr=[2416, 4], y=[64], pos=[1157, 3], name=[64], batch=[1157], ptr=[65])
#
# Step 279:
# =======
# DataBatch(x=[1143, 11], edge_index=[2, 2364], edge_attr=[2364, 4], y=[64], pos=[1143, 3], name=[64], batch=[1143], ptr=[65])
#
# Step 280:
# =======
# DataBatch(x=[1086, 11], edge_index=[2, 2248], edge_attr=[2248, 4], y=[64], pos=[1086, 3], name=[64], batch=[1086], ptr=[65])
#
# Step 281:
# =======
# DataBatch(x=[1112, 11], edge_index=[2, 2278], edge_attr=[2278, 4], y=[64], pos=[1112, 3], name=[64], batch=[1112], ptr=[65])
#
# Step 282:
# =======
# DataBatch(x=[1188, 11], edge_index=[2, 2468], edge_attr=[2468, 4], y=[64], pos=[1188, 3], name=[64], batch=[1188], ptr=[65])
#
# Step 283:
# =======
# DataBatch(x=[1152, 11], edge_index=[2, 2378], edge_attr=[2378, 4], y=[64], pos=[1152, 3], name=[64], batch=[1152], ptr=[65])
#
# Step 284:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2338], edge_attr=[2338, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 285:
# =======
# DataBatch(x=[1133, 11], edge_index=[2, 2346], edge_attr=[2346, 4], y=[64], pos=[1133, 3], name=[64], batch=[1133], ptr=[65])
#
# Step 286:
# =======
# DataBatch(x=[1154, 11], edge_index=[2, 2362], edge_attr=[2362, 4], y=[64], pos=[1154, 3], name=[64], batch=[1154], ptr=[65])
#
# Step 287:
# =======
# DataBatch(x=[1120, 11], edge_index=[2, 2320], edge_attr=[2320, 4], y=[64], pos=[1120, 3], name=[64], batch=[1120], ptr=[65])
#
# Step 288:
# =======
# DataBatch(x=[1178, 11], edge_index=[2, 2426], edge_attr=[2426, 4], y=[64], pos=[1178, 3], name=[64], batch=[1178], ptr=[65])
#
# Step 289:
# =======
# DataBatch(x=[1135, 11], edge_index=[2, 2372], edge_attr=[2372, 4], y=[64], pos=[1135, 3], name=[64], batch=[1135], ptr=[65])
#
# Step 290:
# =======
# DataBatch(x=[1155, 11], edge_index=[2, 2394], edge_attr=[2394, 4], y=[64], pos=[1155, 3], name=[64], batch=[1155], ptr=[65])
#
# Step 291:
# =======
# DataBatch(x=[1179, 11], edge_index=[2, 2420], edge_attr=[2420, 4], y=[64], pos=[1179, 3], name=[64], batch=[1179], ptr=[65])
#
# Step 292:
# =======
# DataBatch(x=[1152, 11], edge_index=[2, 2382], edge_attr=[2382, 4], y=[64], pos=[1152, 3], name=[64], batch=[1152], ptr=[65])
#
# Step 293:
# =======
# DataBatch(x=[1156, 11], edge_index=[2, 2406], edge_attr=[2406, 4], y=[64], pos=[1156, 3], name=[64], batch=[1156], ptr=[65])
#
# Step 294:
# =======
# DataBatch(x=[1162, 11], edge_index=[2, 2386], edge_attr=[2386, 4], y=[64], pos=[1162, 3], name=[64], batch=[1162], ptr=[65])
#
# Step 295:
# =======
# DataBatch(x=[1114, 11], edge_index=[2, 2300], edge_attr=[2300, 4], y=[64], pos=[1114, 3], name=[64], batch=[1114], ptr=[65])
#
# Step 296:
# =======
# DataBatch(x=[1144, 11], edge_index=[2, 2358], edge_attr=[2358, 4], y=[64], pos=[1144, 3], name=[64], batch=[1144], ptr=[65])
#
# Step 297:
# =======
# DataBatch(x=[1198, 11], edge_index=[2, 2478], edge_attr=[2478, 4], y=[64], pos=[1198, 3], name=[64], batch=[1198], ptr=[65])
#
# Step 298:
# =======
# DataBatch(x=[1171, 11], edge_index=[2, 2418], edge_attr=[2418, 4], y=[64], pos=[1171, 3], name=[64], batch=[1171], ptr=[65])
#
# Step 299:
# =======
# DataBatch(x=[1198, 11], edge_index=[2, 2436], edge_attr=[2436, 4], y=[64], pos=[1198, 3], name=[64], batch=[1198], ptr=[65])
#
# Step 300:
# =======
# DataBatch(x=[1151, 11], edge_index=[2, 2350], edge_attr=[2350, 4], y=[64], pos=[1151, 3], name=[64], batch=[1151], ptr=[65])
#
# Step 301:
# =======
# DataBatch(x=[1155, 11], edge_index=[2, 2374], edge_attr=[2374, 4], y=[64], pos=[1155, 3], name=[64], batch=[1155], ptr=[65])
#
# Step 302:
# =======
# DataBatch(x=[1211, 11], edge_index=[2, 2512], edge_attr=[2512, 4], y=[64], pos=[1211, 3], name=[64], batch=[1211], ptr=[65])
#
# Step 303:
# =======
# DataBatch(x=[1161, 11], edge_index=[2, 2388], edge_attr=[2388, 4], y=[64], pos=[1161, 3], name=[64], batch=[1161], ptr=[65])
#
# Step 304:
# =======
# DataBatch(x=[1152, 11], edge_index=[2, 2358], edge_attr=[2358, 4], y=[64], pos=[1152, 3], name=[64], batch=[1152], ptr=[65])
#
# Step 305:
# =======
# DataBatch(x=[1184, 11], edge_index=[2, 2446], edge_attr=[2446, 4], y=[64], pos=[1184, 3], name=[64], batch=[1184], ptr=[65])
#
# Step 306:
# =======
# DataBatch(x=[1132, 11], edge_index=[2, 2368], edge_attr=[2368, 4], y=[64], pos=[1132, 3], name=[64], batch=[1132], ptr=[65])
#
# Step 307:
# =======
# DataBatch(x=[1111, 11], edge_index=[2, 2308], edge_attr=[2308, 4], y=[64], pos=[1111, 3], name=[64], batch=[1111], ptr=[65])
#
# Step 308:
# =======
# DataBatch(x=[1185, 11], edge_index=[2, 2436], edge_attr=[2436, 4], y=[64], pos=[1185, 3], name=[64], batch=[1185], ptr=[65])
#
# Step 309:
# =======
# DataBatch(x=[1135, 11], edge_index=[2, 2346], edge_attr=[2346, 4], y=[64], pos=[1135, 3], name=[64], batch=[1135], ptr=[65])
#
# Step 310:
# =======
# DataBatch(x=[1151, 11], edge_index=[2, 2364], edge_attr=[2364, 4], y=[64], pos=[1151, 3], name=[64], batch=[1151], ptr=[65])
#
# Step 311:
# =======
# DataBatch(x=[1098, 11], edge_index=[2, 2282], edge_attr=[2282, 4], y=[64], pos=[1098, 3], name=[64], batch=[1098], ptr=[65])
#
# Step 312:
# =======
# DataBatch(x=[1106, 11], edge_index=[2, 2262], edge_attr=[2262, 4], y=[64], pos=[1106, 3], name=[64], batch=[1106], ptr=[65])
#
# Step 313:
# =======
# DataBatch(x=[595, 11], edge_index=[2, 1240], edge_attr=[1240, 4], y=[32], pos=[595, 3], name=[32], batch=[595], ptr=[33])

# %%
from torch.nn import Linear, Flatten
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GraphConv, GATv2Conv, MFConv, GENConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, num_node_features, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GraphConv(num_node_features, hidden_channels)
        self.conv2 = GraphConv(hidden_channels, hidden_channels)
        self.conv3 = GENConv(hidden_channels, hidden_channels)
        self.conv4 = MFConv(hidden_channels, hidden_channels)
        
        self.lin = Linear(hidden_channels, 1)

    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        x = x.relu()
        x = self.conv4(x, edge_index)

        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        x = torch.reshape(x, [x.shape[0]])
        
        return x

model = GCN(num_node_features=11, hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GraphConv(11, 64)
#   (conv2): GraphConv(64, 64)
#   (conv3): GENConv(64, 64, aggr=softmax)
#   (conv4): MFConv(64, 64)
#   (lin): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
model = GCN(num_node_features=11, hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.MSELoss()

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = torch.sqrt(criterion(out, data.y))  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()
     name = []
     prediction = []

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         name.append(data['name'])
         pred = model(data.x, data.edge_index, data.batch)
         prediction.append(pred) 

     return name, prediction # Derive ratio of correct predictions.


for epoch in range(1, 100):
    train()
    train_acc = test(train_loader)
    name, pred = test(test_loader)
    print(f'Epoch: {epoch:03d}')
# Out:
# Epoch: 001
# Epoch: 002
# Epoch: 003
# Epoch: 004
# Epoch: 005
# Epoch: 006
# Epoch: 007
# Epoch: 008
# Epoch: 009
# Epoch: 010
# Epoch: 011
# Epoch: 012
# Epoch: 013
# Epoch: 014
# Epoch: 015
# Epoch: 016
# Epoch: 017
# Epoch: 018
# Epoch: 019
# Epoch: 020
# Epoch: 021
# Epoch: 022
# Epoch: 023
# Epoch: 024
# Epoch: 025
# Epoch: 026
# Epoch: 027
# Epoch: 028
# Epoch: 029
# Epoch: 030
# Epoch: 031
# Epoch: 032
# Epoch: 033
# Epoch: 034
# Epoch: 035
# Epoch: 036
# Epoch: 037
# Epoch: 038
# Epoch: 039
# Epoch: 040
# Epoch: 041
# Epoch: 042
# Epoch: 043
# Epoch: 044
# Epoch: 045
# Epoch: 046
# Epoch: 047
# Epoch: 048
# Epoch: 049
# Epoch: 050
# Epoch: 051
# Epoch: 052
# Epoch: 053
# Epoch: 054
# Epoch: 055
# Epoch: 056
# Epoch: 057
# Epoch: 058
# Epoch: 059
# Epoch: 060
# Epoch: 061
# Epoch: 062
# Epoch: 063
# Epoch: 064
# Epoch: 065
# Epoch: 066
# Epoch: 067
# Epoch: 068
# Epoch: 069
# Epoch: 070
# Epoch: 071
# Epoch: 072
# Epoch: 073
# Epoch: 074
# Epoch: 075
# Epoch: 076
# Epoch: 077
# Epoch: 078
# Epoch: 079
# Epoch: 080
# Epoch: 081
# Epoch: 082
# Epoch: 083
# Epoch: 084
# Epoch: 085
# Epoch: 086
# Epoch: 087
# Epoch: 088
# Epoch: 089
# Epoch: 090
# Epoch: 091
# Epoch: 092
# Epoch: 093
# Epoch: 094
# Epoch: 095
# Epoch: 096
# Epoch: 097
# Epoch: 098
# Epoch: 099

# %%
pred_flat = torch.cat(pred)

# %%
pred_flat_np = pred_flat.detach().numpy()

# %%
flat_name = [item for sublist in name for item in sublist]

# %%
import pandas as pd

df = pd.DataFrame({'Idx': flat_name, 'labels':pred_flat_np })
df.to_csv('preditions.csv', sep=',', index=False)

# %%
df
# Out:
#              Idx    labels
# 0      gdb_59377  1.903001
# 1      gdb_14632  4.507661
# 2      gdb_35326  1.485895
# 3      gdb_11448  2.314631
# 4      gdb_35889  4.141517
# ...          ...       ...
# 1995   gdb_99875  3.111997
# 1996   gdb_49868  2.712770
# 1997   gdb_21387  3.624872
# 1998   gdb_89826  2.707370
# 1999  gdb_116298  1.952635
#
# [2000 rows x 2 columns]
